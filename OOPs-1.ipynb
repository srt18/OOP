# %% [markdown]
# # OOP (Object oriented programming)

# %%
l = [1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 l = [1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = 'hello'
# ----> 2 s.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# ![image.png](attachment:7bf3a6c5-4a4f-4287-9524-2a43a0de0acf.png)

# %% [markdown]
# ### Everything in "PYTHON" is "OBJECT"

# %% [markdown]
# 1. Generality to Specificity
# 2. OOP power - It gives power to programmer to build its own datatypes
# ![image.png](attachment:9c3b02db-0577-44eb-85a6-2412818a696c.png)

# %% [markdown]
# ## Class
# 1. Class is a blueprint
# 2. All datatypes in python are built-in classes.
# 3. For example - Cars is Class and Ford is object in class Car
# 4. There are two type of class -- Built-in and User defined classes.
# 5. If there is no object -- There is no use of class.
# ![image.png](attachment:1dd7c0ae-f8a0-4567-a7f7-e4252a911c93.png)

# %%
l = [1,2,3]
print(type(l))
# Out:
# <class 'list'>

# %%
l.upper()
#  list is class and l is variable (its object in class "list")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ![image.png](attachment:a68af632-58cd-4f2e-9f6e-a22100dbb9fb.png)

# %%
# Syntax to create a object 

# objectname = classname()

# %%
#object literal 
l = [1,2]
print(l)
#through list 
la = list()
la
# Out:
# [1, 2]
# []

# %% [markdown]
# ## ATM Machine
# 1. Pascal case - HelloWorld

# %%
class ATM:
    '''
    Builting a ATM machine and there funcitionality 
    '''
    #constructor 
        # Special function -- Have a super power "It automactically execute - it call everytime"
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()
        
    def menu(self):
        user_input = input("""
        HI How can I help you?
        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        if user_input == '1':
            #create pin
            self.create_pin()
        elif user_input == '2':
            #change pin 
            self.change_pin()
        elif user_input == '3':
            #check balance
            self.check_balance()
        elif user_input == '4':
            #withdraw
            self.withdraw()
        else:
            exit()    

    def create_pin(self):
        user_pin = input("Enter your pin")
        self.pin = user_pin

        user_balance = int(input("Enter your balance"))
        self.balance = user_balance

        print("Pin created successfully")
        self.menu()
    
    def change_pin(self):
        old_pin = input("Enter old pin")
        if old_pin == self.pin:
            #let change the pin
            new_pin = input("Enter new pin")
            self.pin = new_pin.pin()
            print("Pin change successfully")
            self.menu()
        else:
            print("Not valid pin")    
            self.menu()
        change_pin = input("")

    def check_balance(self):
        user_pin = input("Enter your pin")
        if user_pin == self.pin:
            print("Your balance is",self.balance)
            self.menu()
        else:
            print("Your balance is empty")
            self.menu()

    def withdraw(self):
        user_input = input("Enter the pin")
        if user_input == self.pin:
            #allow to withdraw
            amount = int(input("Enter the amount"))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print("Withdrawl successful balance is",self.balance)
            else:
                print("Dont have require balance")
        else:    
            print("Your pin is incoorect")
        self.menu()

# %%
# obj.ATM()

# %%
# print(type(obj))
# type(obj)

# %%
L = [1,2,3]
len(L) #length is function -- it's outside the class
L.append(4) #method -- its inside the class

# %% [markdown]
# ## Class diagram
# 1. "+" --> Public
# 2. "-" --> Private
#
# ![image.png](attachment:7714d364-8eb9-4a72-a3c3-703173edcf85.png)

# %% [markdown]
# ### Magic Methods a.k.a Dunker Methods
# -- Python have 1500 special methods --
# 1. Special methods -- Superpower looklikes "__name__"
# 2. __init__ is constructor (special methods - its automatically execute)

# %% [markdown]
# ### Constructor
#  + Its method and have superpower to execute itself automatically
#
#  + Benefit of contructor --> To write configuration related code (Connect with db, connect with internet)
#     1. Example : if god is programmer,earth is class, human-being is object, death is contructor
#     2. In python, renaming of contructor is not possible and "__init__" it always be it is. There will be   only one constructor.
#
#
#  + Self
#     1. Gold Rule -- Gangadhar hi Shantiman hai
#     2. Self is the current object
#     3. Naming of "Self" can be changed

# %%
class fraction():
    '''
    To preform fraction 
    '''
    # parameterized constructor
    def __init__(self,x,y):
        self.num = x
        self.den = y

    def __str__(self): #print you class attritube 
        return '{}/{}'.format(self.num,self.den)
    
    def __add__(self,other): #
        new_num = self.num*other.den + other.num*self.den
        new_den = self.den*other.den

        return '{}/{}'.format(new_num,new_den)

    def __sub__(self,other): #
        new_num = self.num*other.den - other.num*self.den
        new_den = self.den*other.den

        return '{}/{}'.format(new_num,new_den)

    def __mul__(self,other): #
        new_num = self.num*other.num
        new_den = self.den*other.den

        return '{}/{}'.format(new_num,new_den)

    def __truediv__(self,other): #
        new_num = self.num*other.den
        new_den = self.den*other.num

        return '{}/{}'.format(new_num,new_den)

    def convert_to_decimal(self): #Method for decimal
        return self.num/self.den

# %%
a = fraction(3,4)
b = fraction(1,2)
print(a)
print(b)
# Out:
# 3/4
# 1/2

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
b.convert_to_decimal()
# Out:
# 0.5
